# %% [markdown]
# **GPTQ**

# %% [markdown]
# Installing GPTQ and Optimum and downloading calibration dataset

# %%
# !pip3 install auto_gptq
# !pip3 install optimum
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 32.7 MB/s eta 0:00:00
# ...

# %%
# !pip3 install gptqmodel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.3/284.3 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 101.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 4.2 MB/s eta 0:00:00
# ...
#   Created wheel for gptqmodel: filename=gptqmodel-2.2.0-cp311-cp311-linux_x86_64.whl size=3205295 sha256=1ae02ace71a2082451ef5c2f1f9a4047dbf5059846709baa6297dbd6edbe84a7
#   Stored in directory: /root/.cache/pip/wheels/f5/a0/10/12ae1ecaf1676096156195aeeea8ed4787c6eed58d3a00d140
# ...
#   Created wheel for device-smi: filename=device_smi-0.4.1-py3-none-any.whl size=17886 sha256=69bb94efc8f48a271e0cb0111d46e01ddd8de207304195189978be6e6a96c721
# ...

# %%
# !pip3 install datasets

# %%
from datasets import load_dataset
ds = load_dataset("togethercomputer/RedPajama-Data-V2", name="sample", split = 'train', streaming=False)
# Out:
# ...
# fr_middle.json.gz:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# en_middle.json.gz:   0%|          | 0.00/90.5M [00:00<?, ?B/s]
# es_middle.json.gz:   0%|          | 0.00/11.5M [00:00<?, ?B/s]
# en_head.json.gz:   0%|          | 0.00/62.2M [00:00<?, ?B/s]
# ...
# es_middle.signals.json.gz:   0%|          | 0.00/4.87M [00:00<?, ?B/s]
# de_middle.signals.json.gz:   0%|          | 0.00/5.73M [00:00<?, ?B/s]
# es_head.signals.json.gz:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# fr_head.signals.json.gz:   0%|          | 0.00/3.01M [00:00<?, ?B/s]
# it_head.signals.json.gz:   0%|          | 0.00/1.73M [00:00<?, ?B/s]
# es_middle.signals.json.gz:   0%|          | 0.00/4.94M [00:00<?, ?B/s]
# fr_head.signals.json.gz:   0%|          | 0.00/3.00M [00:00<?, ?B/s]
# it_middle.signals.json.gz:   0%|          | 0.00/3.07M [00:00<?, ?B/s]
# es_head.signals.json.gz:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# de_head.signals.json.gz:   0%|          | 0.00/3.70M [00:00<?, ?B/s]
# ...

# %%
import random

from auto_gptq import AutoGPTQForCausalLM, BaseQuantizeConfig

import torch
from transformers import AutoTokenizer
# Out:
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:418: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda:CUDA extension not installed.
# WARNING:auto_gptq.nn_modules.qlinear.qlinear_cuda_old:CUDA extension not installed.

# %%
model_id = "gpt2"
out_dir = "gpt2-gptq-int8"

# %%
quantize_config = BaseQuantizeConfig(
    bits=8,
    group_size=128,
    damp_percent=0.01,
    desc_act=False,
)
model = AutoGPTQForCausalLM.from_pretrained(model_id, quantize_config)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
text = ''
for batch in ds.take(3):
    text = text + batch['raw_content']

# %%
tokenized_data = tokenizer(text, return_tensors='pt')

# %%
examples_ids = []
for _ in range(3):
    i = random.randint(0, tokenized_data.input_ids.shape[1] - tokenizer.model_max_length - 1)
    j = i + tokenizer.model_max_length
    input_ids = tokenized_data.input_ids[:, i:j]
    attention_mask = torch.ones_like(input_ids)
    examples_ids.append({'input_ids': input_ids, 'attention_mask': attention_mask})

# %%
# %time


model.quantize(
    examples_ids,
    batch_size=1,
    use_triton=True,
)


model.save_quantized(out_dir, use_safetensors=True)
tokenizer.save_pretrained(out_dir)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs
# INFO - Start quantizing layer 1/12
# INFO:auto_gptq.modeling._base:Start quantizing layer 1/12
# INFO - Quantizing attn.c_attn in layer 1/12...
# INFO:auto_gptq.modeling._base:Quantizing attn.c_attn in layer 1/12...
# INFO - Quantizing attn.c_proj in layer 1/12...
# INFO:auto_gptq.modeling._base:Quantizing attn.c_proj in layer 1/12...
# INFO - Quantizing mlp.c_fc in layer 1/12...
# INFO:auto_gptq.modeling._base:Quantizing mlp.c_fc in layer 1/12...
# INFO - Quantizing mlp.c_proj in layer 1/12...
# INFO:auto_gptq.modeling._base:Quantizing mlp.c_proj in layer 1/12...
# INFO - Start quantizing layer 2/12
# INFO:auto_gptq.modeling._base:Start quantizing layer 2/12
# INFO - Quantizing attn.c_attn in layer 2/12...
# INFO:auto_gptq.modeling._base:Quantizing attn.c_attn in layer 2/12...
# INFO - Quantizing attn.c_proj in layer 2/12...
# INFO:auto_gptq.modeling._base:Quantizing attn.c_proj in layer 2/12...
# ...

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"


model = AutoGPTQForCausalLM.from_quantized(
    out_dir,
    device=device,
    use_triton=True,
    use_safetensors=True,
)
tokenizer = AutoTokenizer.from_pretrained(out_dir)
# Out:
# WARNING - Exllamav2 kernel is not installed, reset disable_exllamav2 to True. This may because you installed auto_gptq using a pre-build wheel on Windows, in which exllama_kernels are not compiled. To use exllama_kernels to further speedup inference, you can re-install auto_gptq from source.
# WARNING:auto_gptq.modeling._base:Exllamav2 kernel is not installed, reset disable_exllamav2 to True. This may because you installed auto_gptq using a pre-build wheel on Windows, in which exllama_kernels are not compiled. To use exllama_kernels to further speedup inference, you can re-install auto_gptq from source.
# WARNING - CUDA kernels for auto_gptq are not installed, this will result in very slow inference speed. This may because:
# 1. You disabled CUDA extensions compilation by setting BUILD_CUDA_EXT=0 when install auto_gptq from source.
# 2. You are using pytorch without CUDA support.
# 3. CUDA and nvcc are not installed in your device.
# ...

# %%
from transformers import pipeline

generator = pipeline('text-generation', model=model, tokenizer=tokenizer)

result = generator("I'm trying to", do_sample=True, max_length=50)[0]['generated_text']
print(result)
# Out:
# Device set to use cuda:0
# ...

# %% [markdown]
# Installing huggingface_hub to push model

# %%
# !pip install huggingface_hub

# %% [markdown]
# Logging in

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# Uploading model to hf hub

# %%
model.push_to_hub("gpt2-gptq-int8")
tokenizer.push_to_hub("gpt2-gptq-int8")
# Out:
# INFO - Uploading the following files to RincewindTheWizard/gpt2-gptq-int8: merges.txt,special_tokens_map.json,vocab.json,tokenizer_config.json,quantize_config.json,gptq_model-8bit-128g.safetensors,tokenizer.json,config.json
# INFO:auto_gptq.modeling._base:Uploading the following files to RincewindTheWizard/gpt2-gptq-int8: merges.txt,special_tokens_map.json,vocab.json,tokenizer_config.json,quantize_config.json,gptq_model-8bit-128g.safetensors,tokenizer.json,config.json
# gptq_model-8bit-128g.safetensors:   0%|          | 0.00/243M [00:00<?, ?B/s]
# ...

# %% [markdown]
# **Installing lm-eval (benchmarks)**

# %%
# !pip3 install lm-eval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 2.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 58.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 7.9 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=8a840046980165cd4f365e5281e2253eb452ba175482d93b0c415304ed1bcedb
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# ...

# %%
from tqdm import tqdm

# %% [markdown]
# **Pre-trained gpt2 :**

# %% [markdown]
# Winogrande

# %%
# !lm_eval --model hf\
    --model_args pretrained=openai-community/gpt2 \
    --tasks winogrande \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2025-04-05 10:43:51.440394: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743849831.460467    4517 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743849831.466620    4517 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-05:10:44:08,770 INFO     [lm_eval.__main__:379] Selected Tasks: ['winogrande']
# 2025-04-05:10:44:08,772 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# ...

# %% [markdown]
# BoolQ

# %%
# !lm_eval --model hf\
    --model_args pretrained=openai-community/gpt2,trust_remote_code=True \
    --tasks boolq \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2025-04-05 10:52:57.726415: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743850377.746307    7002 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743850377.752366    7002 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-05:10:53:14,314 INFO     [lm_eval.__main__:379] Selected Tasks: ['boolq']
# 2025-04-05:10:53:14,315 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# ...

# %% [markdown]
# **Quantized and uploaded model**

# %% [markdown]
# Winogrande

# %%
# !lm_eval --model hf\
    --model_args pretrained=RincewindTheWizard/gpt2-gptq-int8 \
    --tasks winogrande \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2025-04-05 10:40:58.529387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743849658.585713    3569 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743849658.594895    3569 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-05:10:41:16,145 INFO     [lm_eval.__main__:379] Selected Tasks: ['winogrande']
# 2025-04-05:10:41:16,147 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# ...

# %% [markdown]
# BoolQ

# %%
# !lm_eval --model hf\
    --model_args pretrained=RincewindTheWizard/gpt2-gptq-int8,trust_remote_code=True \
    --tasks boolq \
    --device cuda:0 \
    --batch_size 8
# Out:
# 2025-04-05 10:54:57.082272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743850497.102303    7556 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743850497.108434    7556 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-05:10:55:13,798 INFO     [lm_eval.__main__:379] Selected Tasks: ['boolq']
# 2025-04-05:10:55:13,799 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# ...

# %% [markdown]
# Now let's download model from hf-hub

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from auto_gptq import AutoGPTQForCausalLM
import gptqmodel
import optimum
import torch

model_name = "RincewindTheWizard/gpt2-gptq"

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# INFO  ENV: Auto setting PYTORCH_CUDA_ALLOC_CONF='expandable_segments:True' for memory saving.
# INFO  ENV: Auto setting CUDA_DEVICE_ORDER=PCI_BUS_ID for correctness.
# tokenizer_config.json:   0%|          | 0.00/475 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"


model = AutoGPTQForCausalLM.from_quantized(
    model_name,
    device=device,
    use_triton=True,
    use_safetensors=True,
)
# Out:
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# WARNING - Exllamav2 kernel is not installed, reset disable_exllamav2 to True. This may because you installed auto_gptq using a pre-build wheel on Windows, in which exllama_kernels are not compiled. To use exllama_kernels to further speedup inference, you can re-install auto_gptq from source.
# WARNING:auto_gptq.modeling._base:Exllamav2 kernel is not installed, reset disable_exllamav2 to True. This may because you installed auto_gptq using a pre-build wheel on Windows, in which exllama_kernels are not compiled. To use exllama_kernels to further speedup inference, you can re-install auto_gptq from source.
# WARNING - CUDA kernels for auto_gptq are not installed, this will result in very slow inference speed. This may because:
# 1. You disabled CUDA extensions compilation by setting BUILD_CUDA_EXT=0 when install auto_gptq from source.
# 2. You are using pytorch without CUDA support.
# ...
